# %% [markdown]
# # 作業1：
# ## 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
# ### Trending YouTube Video Statistics  https://www.kaggle.com/datasnaek/youtube-new (熱門YouTube視頻的每日統計信息)
#
# ### 1. 你選的這組資料為何重要
# #### Ans:企業的核⼼心問題
#
# ### 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
# #### Ans:數據集是使用YouTube API收集的
#
# ### 3. 蒐集而來的資料型態為何
# #### Ans:結構式資料
#
# ### 4. 這組資料想解決的問題如何評估
# #### Ans:可以視為分類、分群問題。

# %% [markdown]
# # 作業2：
# ### 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
#
# ### 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
# #### Ans:
# * 分析顧客在甚麼時候、甚麼時間、希望(或習慣)透過哪種方式來叫車  ==>  針對顧客的問卷。
# * 分析在哪個地區的載客量較高，在車輛的調配上針對結果去做分配，提高載客量  ==>  針對司機的問券。
#
# ### 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
# #### Ans:
# * 平時載客時，可透過車輛中的小螢幕，來做調查(顧客問卷)。
# * 透過車隊的APP，使用獎勵機制，來鼓勵使用者填寫問卷(顧客問卷)。
# * 請司機記錄(路邊轎車)顧客上車地點、時段，由APP叫車的則由系統轉換成數據(司機問卷)。
#
# ### 3. 蒐集而來的資料型態為何
# #### Ans:
# * 顧客問卷為結構化資料
# * 司機問卷為結構化資料
#
# ### 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
# #### Ans:
# * Accuracy
# * ROC

# %% [markdown]
# # 作業3：
# #### 請點選下方檢視範例依照 Day_001_example_of_metrics.ipynb 完成 Mean Squared Error 的函式
# # ![image.png](attachment:image.png)
# #### 資料夾結構建立規則提醒：ML100 > data資料夾 & homework資料夾 (ipynb檔) (請注意data的存放位置，建議放在*.ipynb 同一個目錄下，這樣才能在不修改code的情況下 正常執行)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_absolute_error(y,yi):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yi: 預測值
    Return:
        - mae: MAE
    """
    mae=MAE=sum (abs(y-yi)) / len(y)
    return mae

#定義 mean_squared_error 這個函數, 計算並傳回 MSE
def mean_squared_error(y, yi):
    return sum ((y - yi)**2) / len (y)

# %%
w = 3
b = 0.5
x_lin = np.linspace(0, 100, 101)
y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 193.165
# The Mean absolute error is 10.922
